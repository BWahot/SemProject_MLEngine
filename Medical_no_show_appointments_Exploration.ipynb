# %% [markdown]
# <a href="https://colab.research.google.com/github/BravoTM/SemProject_MLEngine/blob/main/Medical_no_show_appointments_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@ number of rows and columns

110527 rows X 14 columns

# %%
#@ Datatypes
integers example (sms_received,diabetes)
floating-point deciaml numbers example (2.987)
strings example (gender(F OR M))

# %%
#@ Is dataset complete
Yes, the dataset is complete.
Running df.isnull().sum() returns 0 missing values for all 14 columns across all 110,527 rows, meaning there are no null, NaN, or empty entries in the dataset.
